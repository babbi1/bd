# %% [markdown]
# <a href="https://colab.research.google.com/github/babbi1/bd/blob/master/ceshi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def bmr():
    print('您好，我可以帮您计算基础代谢率；')
    a=input('需要计算请输入"bmr",如退出请输入"q"：')

    while a=='bmr' or a=='BMR':
        print("请输入以下信息，空格分割")
        str=input("性别 体重(kg） 身高（cm） 年龄：")
        strlist=str.split(" ")
        print(strlist)
        print('您是{}性,今年{}岁，重{}kg,身高{}cm对吗？'.format(strlist[0],strlist[-1],strlist[1],strlist[2]))
        xb = strlist[0]
        nl = float(strlist[-1])
        tz = float(strlist[1])
        sg = float(strlist[-1])
        if xb=='男':
            bmrna = (13.7 * tz) + (5.0 * sg) - ( 6.8 * nl)+66
            print('您的基础代谢率为：',bmrna)
        elif xb == '女':
            bmrnv = (9.6 * tz) + (1.0 * sg) - (4.7 * nl)+655
            print('您的基础代谢率为：',bmrnv)
        a=input('需要计算请输入"bmr",如退出请输入"q"：')

    else:
        input("退出请按回车")

bmr()
# Out:
# 您好，我可以帮您计算基础代谢率；
# 需要计算请输入"bmr",如退出请输入"q"：bmr
# 请输入以下信息，空格分割
# 性别 体重(kg） 身高（cm） 年龄：男 50 176 24
# ['男', '50', '176', '24']
# 您是男性,今年24岁，重50kg,身高176cm对吗？
# 您的基础代谢率为： 707.8
# 需要计算请输入"bmr",如退出请输入"q"：环境
# 退出请按回车
